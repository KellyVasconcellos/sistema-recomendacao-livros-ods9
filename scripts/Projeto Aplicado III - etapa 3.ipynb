# %% [markdown]
# <a href="https://colab.research.google.com/github/Wesrsant/projetoaplicadomackenzie_III/blob/main/Projeto%20Aplicado%20III%20-%20etapa%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Projeto Aplicado III

# %%
# Importação das bibliotecas

import pandas as pd
import io
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %%
# Carregando o dataframe das avaliações dos livros

df_book_ratings = pd.read_csv('BX-Book-Ratings.csv',sep=';', encoding='latin-1')
df_books = pd.read_csv('BX_Books.csv', sep=';', encoding='latin-1')

# %%
# Removendo notas zero (conforme etapa de Análise Exploratória de Dados***)

df_book_ratings = df_book_ratings[df_book_ratings['Book-Rating'] > 0].copy()

# %%
# Filtrar usuários com mínimo de 3 avaliações

user_counts = df_book_ratings['User-ID'].value_counts()
min_user_ratings = 3
usuarios_ativos = user_counts[user_counts >= min_user_ratings].index
filtro_usuarios_ativos = df_book_ratings['User-ID'].isin(usuarios_ativos)
df_br_filtrado = df_book_ratings[filtro_usuarios_ativos].copy()

# %%
# Filtrar livros com menos de 10 avaliações

book_counts = df_br_filtrado['ISBN'].value_counts()
min_book_ratings = 10
livros_populares = book_counts[book_counts >= min_book_ratings].index
filtro_livros_populares = df_br_filtrado['ISBN'].isin(livros_populares)
df_br_filtrado = df_br_filtrado[filtro_livros_populares].copy()

# %%
df_book_ratings.info() # Quantidade de linhas do dataset após remoção de notas zero: 433671
print(df_book_ratings['ISBN'].nunique()) # Quantidade de livros do dataset após remoção de notas zero
print(df_book_ratings['User-ID'].nunique()) # Quantidade de usuários do dataset após remoção de notas zero
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 433671 entries, 1 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   User-ID      433671 non-null  int64
#  1   ISBN         433671 non-null  object
#  2   Book-Rating  433671 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 13.2+ MB
# 185973
# 77805

# %%
df_br_filtrado.info() # Quantidade de linhas após a filtragem de mínimo de avaliações: 110016
print(df_br_filtrado['ISBN'].nunique()) # Quantidade de livros da base filtrada
print(df_br_filtrado['User-ID'].nunique()) # Quantidade de usuários da base filtrada
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 110016 entries, 16 to 1149771
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   User-ID      110016 non-null  int64
#  1   ISBN         110016 non-null  object
#  2   Book-Rating  110016 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ MB
# 4585
# 17424

# %%
# Criando a matriz de usuário-item (atenção c/ performance e memória RAM)

rating_matrix = df_br_filtrado.pivot_table(index='User-ID', columns='ISBN', values='Book-Rating').fillna(0)
rating_matrix_sparse = csr_matrix(rating_matrix.values)

# %%
# Exportando matriz para CSV
rating_matrix.to_csv('rating_matrix.csv')

# %%
print(rating_matrix_sparse.shape) # Linhas e colunas da matriz esparsa
# Out:
# (17424, 4585)

# %%
# Aplicando o algoritmo KNN com 30 vizinhos próximos

knn_model = NearestNeighbors(metric='cosine', n_neighbors=30)
knn_model.fit(rating_matrix_sparse)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=30)

# %%
### FUNÇÃO GERAR RECOMENDAÇÕES POR ID ###
# Criando uma função para buscar recomendações de livros com base no ID do usuário

def gerar_recomendacoes_por_id(df_br_filtrado, rating_matrix, rating_matrix_sparse, knn_model, user_id, n_neighbors=31, n_recomendacoes=10):

    # Verificando se o user_id é válido para nossa matriz
    if user_id not in rating_matrix.index:
        return "Usuário não encontrado :("

    # Encontrar a posição do usuário na matriz
    index_usuario = rating_matrix.index.get_loc(user_id)

    # Extraindo a linha completa de avaliações do usuário de acordo com user_id
    avaliacoes_usuario = rating_matrix_sparse[index_usuario]

    # Encontrar os vizinhos mais proximos (30 vizinhos)
    distancias, indices = knn_model.kneighbors(avaliacoes_usuario, n_neighbors)

    # Obter os IDs dos usuários vizinhos (excluindo o próprio usuário)
    lista_indices = indices.flatten()
    ids_vizinhos = rating_matrix.index[lista_indices][1:]

    # Coletar os livros avaliados pelos vizinhos
    filtro_vizinhos = df_br_filtrado['User-ID'].isin(ids_vizinhos)
    livros_vizinhos = set(df_br_filtrado[filtro_vizinhos]['ISBN'].unique())

    # Remover livros que o usuário já avaliou
    filtro_usuario = df_br_filtrado['User-ID'] == user_id
    livros_lidos = set(df_br_filtrado[filtro_usuario]['ISBN'].unique())

    # Obtendo o conjunto de livros vizinhos excetuando os livros já avaliados pelo próprio usuário
    livros_vizinhos_unicos = livros_vizinhos - livros_lidos

    # Gerando um dataframe apenas com as avaliações feitas pelos vizinhos
    df_avaliacoes_vizinhos = df_br_filtrado[filtro_vizinhos]

    # Gerando um dataframe com contagem e média
    df_ranking = df_avaliacoes_vizinhos[df_avaliacoes_vizinhos['ISBN'].isin(livros_vizinhos_unicos)].copy()
    contagem_e_media = df_ranking.groupby('ISBN')['Book-Rating'].agg(['count', 'mean']).reset_index()

    # Extraindo um dataframe apenas com os N livros recomendados
    livros_recomendados = contagem_e_media.sort_values(by=['mean', 'count'], ascending=[False, False]).head(n_recomendacoes)

    # Criando um merge dos livros recomendados com o dataframe df_books
    livros_recomendados_pareados = pd.merge(livros_recomendados, df_books, on='ISBN')

    # Verificando se há livros recomendados em número suficiente para atender o número de recomendações
    # Se não, irá gerar o número máximo de livros que possui entre os recomendados
    if (len(livros_recomendados_pareados) < n_recomendacoes):
        n_recomendacoes = len(livros_recomendados_pareados)

    # Clicando um laço para printar as recomendações de livros para o usuário
    print("--------------------------------------------------------")
    print("Veja seus livros recomendados:")
    print("--------------------------------------------------------")
    for i in range(n_recomendacoes):
        print(f"{i+1}. ''{livros_recomendados_pareados.iloc[i]['Book-Title']}'' - {livros_recomendados_pareados.iloc[i]['Book-Author']} - Editora: {livros_recomendados_pareados.iloc[i]['Publisher']}")
    print("--------------------------------------------------------")

# %%
### EXECUTANDO FUNÇÃO GERAR RECOMENDAÇÕES POR ID ###

# Executando a função para gerar recomendações de acordo com o usuário de id específico
# exemplos: 503, 1184, 3106, 7650, 110497, 164696, 208936, 239535, 269692, 278844

gerar_recomendacoes_por_id(df_br_filtrado, rating_matrix, rating_matrix_sparse, knn_model, 503)
# Out:
# --------------------------------------------------------
# Veja seus livros recomendados:
# --------------------------------------------------------
# 1. ''Notes from a Small Island'' - Bill Bryson - Editora: Perennial
# 2. ''A Confederacy of Dunces (Evergreen Book)'' - John Kennedy Toole - Editora: Grove Press
# 3. ''A Man Named Dave: A Story of Triumph and Forgiveness'' - David J. Pelzer - Editora: Plume Books
# 4. ''The Lovely Bones: A Novel'' - Alice Sebold - Editora: Little, Brown
# 5. ''A Heartbreaking Work of Staggering Genius'' - Dave Eggers - Editora: Vintage Books USA
# 6. ''Bel Canto: A Novel'' - Ann Patchett - Editora: Perennial
# 7. ''Paris to the Moon'' - Adam Gopnik - Editora: Random House Trade
# 8. ''Evening Class'' - Maeve Binchy - Editora: Dell Publishing Company
# 9. ''A Painted House'' - John Grisham - Editora: Dell Publishing Company
# --------------------------------------------------------

# %%
### FUNÇÃO NOVO USUÁRIO ###

def novo_usuario(df_br_filtrado, rating_matrix, knn_model, df_books, n_recomendacoes=10):

    # A função irá gerar um novo usuário, apresentar uma lista de livros populares,
    # registrar as preferências e gerar recomendações específicas para esse novo usuário.

    # Gerando o id do novo usuário
    novo_user_id = 99999999

    # Determinando número de sugestões
    sugestoes = 500

    # Armazenando em um index os livros mais populares da base
    top_livros = df_br_filtrado['ISBN'].value_counts().head(sugestoes+1).index

    # Transformando o index em um dataframe
    df_top_livros = pd.DataFrame(top_livros, columns=['ISBN'])

    # Fazendo um merge com a base de livros
    df_top_pareados = pd.merge(df_top_livros, df_books, on='ISBN')

    # Printando o título e o autor dos livros mais populares do dataset
    print("Lista de livros:")
    print("--------------------------------------------------------")
    for i in range(len(df_top_pareados)):
        print(f"{i+1}. ''{df_top_pareados.iloc[i]['Book-Title']}'' - {df_top_pareados.iloc[i]['Book-Author']}")

    # Gerando uma lista vazia com os livros escolhidos
    livros_escolhidos = []

    # Printando as instruções na tela.
    print("\n--------------------------------------------------------")
    print("\nEstamos criando um novo perfil de usuário.")
    print("Nesse momento, solicitamos por favor os seus três livros favoritos da lista acima.\n")
    print("--------------------------------------------------------")
    print("\nInsira por favor o número dos três livros: (digite 0 para sair)")

    # Recebendo o input dos números referentes aos livros escolhidos
    while(len(livros_escolhidos)<3):
        # o try impede letras, numeros decimais etc.
        try:
            numero = int(input())
            # o if impede numeros fora do intervalo
            if(1<=numero<=sugestoes):
                livros_escolhidos.append(numero)
                titulo = df_top_pareados.iloc[numero-1]['Book-Title']
                print("Livro escolhido registrado com sucesso! Título: ", titulo)
            elif(numero == 0):
                # se for digitado zero, o programa sairá do laço
                break
            else:
                print("Número inválido! Tente novamente.")
                continue
        except:
            print("Entrada inválida! Tente novamente.")

    # O if abaixo é para garantir que a lista de livros escolhidos tem o tamanho correto
    if (len(livros_escolhidos)==3):

        print("Processando...")

        # Ajustamos os números escolhidos para os índices do dataframe (subtraímos 1 do valor)
        indices_df = [num - 1 for num in livros_escolhidos]

        # Criando um dataframe
        df_livros_escolhidos = df_top_pareados.iloc[indices_df]

        # Extrair os ISBNs dos livros selecionados para uma lista
        isbns_escolhidos = df_livros_escolhidos['ISBN'].tolist()

        # Criar uma lista vazia para guardar as novas avaliações
        lista_novas_avaliacoes = []

        # Criando um dicionário com as novas avaliações para cada ISBN
        for isbn in isbns_escolhidos:
            nova_avaliacao = {
                'User-ID': novo_user_id,
                'ISBN': isbn,
                'Book-Rating': 10
            }
            lista_novas_avaliacoes.append(nova_avaliacao)

        # Transformar a lista de novas avaliações em um dataframe
        df_novas_avaliacoes = pd.DataFrame(lista_novas_avaliacoes)

        # Agora vamos concatenar os dois dataframes (o dataframe original e aquele com as novas avaliações)
        df_br_atualizado = pd.concat([df_br_filtrado, df_novas_avaliacoes], ignore_index=True)

        # Atualizando a rating_matrix
        rating_matrix_atualizada = df_br_atualizado.pivot_table(index='User-ID', columns='ISBN', values = 'Book-Rating').fillna(0)
        rating_matrix_sparse_atualizada = csr_matrix(rating_matrix_atualizada.values)

        # Treinando o modelo com o novo usuário
        knn_model_novo = NearestNeighbors(metric='cosine', n_neighbors=31)
        knn_model_novo.fit(rating_matrix_sparse_atualizada)

        print("\n")
        # Agora chamando a função para gerar recomendações com id passando o id do novo usuário que acabamos de criar
        gerar_recomendacoes_por_id(df_br_atualizado, rating_matrix_atualizada, rating_matrix_sparse_atualizada, knn_model_novo, novo_user_id, n_neighbors=31,n_recomendacoes=10)

    # Caso o operador tenha escolhido a opção zero, o programa termina
    else:
        print("Até mais ;)")

# %%
# EXECUTANDO FUNÇÃO DE NOVO USUÁRIO

novo_usuario(df_br_filtrado, rating_matrix, knn_model, df_books, 10)
# Out:
# Lista de livros:
# --------------------------------------------------------
# 1. ''The Lovely Bones: A Novel'' - Alice Sebold
# 2. ''The Da Vinci Code'' - Dan Brown
# 3. ''Wild Animus'' - Rich Shapero
# 4. ''The Red Tent (Bestselling Backlist)'' - Anita Diamant
# 5. ''Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))'' - J. K. Rowling
# 6. ''Divine Secrets of the Ya-Ya Sisterhood: A Novel'' - Rebecca Wells
# 7. ''The Secret Life of Bees'' - Sue Monk Kidd
# 8. ''Angels & Demons'' - Dan Brown
# 9. ''Where the Heart Is (Oprah's Book Club (Paperback))'' - Billie Letts
# 10. ''Girl with a Pearl Earring'' - Tracy Chevalier
# 11. ''The Pilot's Wife : A Novel'' - Anita Shreve
# 12. ''Interview with the Vampire'' - Anne Rice
# 13. ''A Painted House'' - John Grisham
# 14. ''Snow Falling on Cedars'' - David Guterson
# 15. ''The Five People You Meet in Heaven'' - Mitch Albom
# 16. ''Good in Bed'' - Jennifer Weiner
# 17. ''Life of Pi'' - Yann Martel
# 18. ''The Catcher in the Rye'' - J.D. Salinger
# 19. ''Harry Potter and the Order of the Phoenix (Book 5)'' - J. K. Rowling
# 20. ''The Firm'' - John Grisham
# 21. ''To Kill a Mockingbird'' - Harper Lee
# 22. ''Jurassic Park'' - Michael Crichton
# 23. ''A Time to Kill'' - JOHN GRISHAM
# 24. ''House of Sand and Fog'' - Andre Dubus III
# 25. ''She's Come Undone (Oprah's Book Club)'' - Wally Lamb
# 26. ''The Poisonwood Bible: A Novel'' - Barbara Kingsolver
# 27. ''She's Come Undone (Oprah's Book Club (Paperback))'' - Wally Lamb
# 28. ''The Joy Luck Club'' - Amy Tan
# 29. ''The Nanny Diaries: A Novel'' - Emma McLaughlin
# 30. ''Harry Potter and the Chamber of Secrets (Book 2)'' - J. K. Rowling
# 31. ''Little Altars Everywhere: A Novel'' - Rebecca Wells
# 32. ''Summer Sisters'' - Judy Blume
# 33. ''The Notebook'' - Nicholas Sparks
# 34. ''Tuesdays with Morrie: An Old Man, a Young Man, and Life's Greatest Lesson'' - MITCH ALBOM
# 35. ''Timeline'' - MICHAEL CRICHTON
# 36. ''The No. 1 Ladies' Detective Agency (Today Show Book Club #8)'' - Alexander McCall Smith
# 37. ''The Pelican Brief'' - John Grisham
# 38. ''The Testament'' - John Grisham
# 39. ''The Summons'' - John Grisham
# 40. ''A Prayer for Owen Meany'' - John Irving
# 41. ''The Nanny Diaries: A Novel'' - Emma McLaughlin
# 42. ''Confessions of a Shopaholic (Summer Display Opportunity)'' - SOPHIE KINSELLA
# 43. ''The Divine Secrets of the Ya-Ya Sisterhood: A Novel'' - Rebecca Wells
# 44. ''1st to Die: A Novel'' - James Patterson
# 45. ''The Hobbit : The Enchanting Prelude to The Lord of the Rings'' - J.R.R. TOLKIEN
# 46. ''The Vampire Lestat (Vampire Chronicles, Book II)'' - ANNE RICE
# 47. ''White Oleander : A Novel (Oprah's Book Club)'' - Janet Fitch
# 48. ''Red Dragon'' - Thomas Harris
# 49. ''Harry Potter and the Prisoner of Azkaban (Book 3)'' - J. K. Rowling
# 50. ''The Client'' - John Grisham
# 51. ''Wicked: The Life and Times of the Wicked Witch of the West'' - Gregory Maguire
# 52. ''Stupid White Men ...and Other Sorry Excuses for the State of the Nation!'' - Michael Moore
# 53. ''Me Talk Pretty One Day'' - David Sedaris
# 54. ''The Girls' Guide to Hunting and Fishing'' - Melissa Bank
# 55. ''Harry Potter and the Goblet of Fire (Book 4)'' - J. K. Rowling
# 56. ''The Runaway Jury'' - JOHN GRISHAM
# 57. ''Midwives: A Novel'' - Chris Bohjalian
# 58. ''The Bridges of Madison County'' - Robert James Waller
# 59. ''Fahrenheit 451'' - RAY BRADBURY
# 60. ''Fast Food Nation: The Dark Side of the All-American Meal'' - Eric Schlosser
# 61. ''Left Behind: A Novel of the Earth's Last Days (Left Behind No. 1)'' - Tim Lahaye
# 62. ''Harry Potter and the Chamber of Secrets (Book 2)'' - J. K. Rowling
# 63. ''Harry Potter and the Prisoner of Azkaban (Book 3)'' - J. K. Rowling
# 64. ''Bel Canto: A Novel'' - Ann Patchett
# 65. ''The Chamber'' - John Grisham
# 66. ''The Partner'' - John Grisham
# 67. ''The Brethren'' - John Grisham
# 68. ''Sphere'' - MICHAEL CRICHTON
# 69. ''Lucky : A Memoir'' - Alice Sebold
# 70. ''American Gods'' - Neil Gaiman
# 71. ''Bridget Jones's Diary'' - Helen Fielding
# 72. ''The Fellowship of the Ring (The Lord of the Rings, Part 1)'' - J.R.R. TOLKIEN
# 73. ''The Reader'' - Bernhard Schlink
# 74. ''The Rainmaker'' - JOHN GRISHAM
# 75. ''A Heartbreaking Work of Staggering Genius'' - Dave Eggers
# 76. ''One for the Money (Stephanie Plum Novels (Paperback))'' - Janet Evanovich
# 77. ''SHIPPING NEWS'' - Annie Proulx
# 78. ''Empire Falls'' - Richard Russo
# 79. ''The Horse Whisperer'' - Nicholas Evans
# 80. ''We Were the Mulvaneys'' - Joyce Carol Oates
# 81. ''ANGELA'S ASHES'' - Frank McCourt
# 82. ''Harry Potter and the Sorcerer's Stone (Book 1)'' - J. K. Rowling
# 83. ''Balzac and the Little Chinese Seamstress : A Novel'' - DAI SIJIE
# 84. ''Two for the Dough'' - Janet Evanovich
# 85. ''Angela's Ashes (MMP) : A Memoir'' - Frank McCourt
# 86. ''Neverwhere'' - Neil Gaiman
# 87. ''Girl, Interrupted'' - SUSANNA KAYSEN
# 88. ''Into Thin Air : A Personal Account of the Mt. Everest Disaster'' - JON KRAKAUER
# 89. ''Nickel and Dimed: On (Not) Getting By in America'' - Barbara Ehrenreich
# 90. ''The Hours: A Novel'' - Michael Cunningham
# 91. ''The Alienist'' - Caleb Carr
# 92. ''Bridget Jones: The Edge of Reason'' - Helen Fielding
# 93. ''Cold Mountain : A Novel'' - CHARLES FRAZIER
# 94. ''A Walk to Remember'' - Nicholas Sparks
# 95. ''Icy Sparks'' - Gwyn Hyman Rubio
# 96. ''Harry Potter and the Goblet of Fire (Book 4)'' - J. K. Rowling
# 97. ''A Child Called \It\": One Child's Courage to Survive"'' - Dave Pelzer
# 98. ''The Street Lawyer'' - JOHN GRISHAM
# 99. ''Silence of the Lambs'' - Thomas Harris
# 100. ''Four To Score (A Stephanie Plum Novel)'' - Janet Evanovich
# 101. ''The Bad Beginning (A Series of Unfortunate Events, Book 1)'' - Lemony Snicket
# 102. ''Prodigal Summer: A Novel'' - Barbara Kingsolver
# 103. ''STONES FROM THE RIVER'' - Ursula Hegi
# 104. ''Message in a Bottle'' - Nicholas Sparks
# 105. ''White Oleander : A Novel'' - Janet Fitch
# 106. ''Along Came a Spider (Alex Cross Novels)'' - James Patterson
# 107. ''The Book of Ruth (Oprah's Book Club (Paperback))'' - Jane Hamilton
# 108. ''Lord of the Flies'' - William Gerald Golding
# 109. ''While I Was Gone'' - Sue Miller
# 110. ''Ender's Game (Ender Wiggins Saga (Paperback))'' - Orson Scott Card
# 111. ''The Perfect Storm : A True Story of Men Against the Sea'' - Sebastian Junger
# 112. ''The Handmaid's Tale'' - Margaret Atwood
# 113. ''The Bean Trees'' - Barbara Kingsolver
# 114. ''Skipping Christmas'' - JOHN GRISHAM
# 115. ''A Is for Alibi (Kinsey Millhone Mysteries (Paperback))'' - SUE GRAFTON
# 116. ''Into the Wild'' - Jon Krakauer
# 117. ''Fall On Your Knees (Oprah #45)'' - Ann-Marie MacDonald
# 118. ''Midnight in the Garden of Good and Evil: A Savannah Story'' - John Berendt
# 119. ''The Queen of the Damned (Vampire Chronicles (Paperback))'' - Anne Rice
# 120. ''Mystic River'' - Dennis Lehane
# 121. ''Full House (Janet Evanovich's Full Series)'' - Janet Evanovich
# 122. ''The Witching Hour (Lives of the Mayfair Witches)'' - ANNE RICE
# 123. ''Seabiscuit: An American Legend'' - LAURA HILLENBRAND
# 124. ''Dance upon the Air (Three Sisters Island Trilogy)'' - Nora Roberts
# 125. ''1984'' - George Orwell
# 126. ''Confessions of an Ugly Stepsister : A Novel'' - Gregory Maguire
# 127. ''Hannibal'' - Thomas Harris
# 128. ''Three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel)'' - Janet Evanovich
# 129. ''The Great Gatsby'' - F. Scott Fitzgerald
# 130. ''When the Wind Blows'' - James Patterson
# 131. ''2nd Chance'' - James Patterson
# 132. ''Tears of the Giraffe (No.1 Ladies Detective Agency)'' - Alexander McCall Smith
# 133. ''The Tale of the Body Thief (Vampire Chronicles (Paperback))'' - Anne Rice
# 134. ''From Potter's Field'' - Patricia Daniels Cornwell
# 135. ''The Sweet Potato Queens' Book of Love'' - JILL CONNER BROWNE
# 136. ''Outlander'' - DIANA GABALDON
# 137. ''Watership Down'' - Richard Adams
# 138. ''Shopaholic Takes Manhattan (Summer Display Opportunity)'' - Sophie Kinsella
# 139. ''Dude, Where's My Country?'' - Michael Moore
# 140. ''Congo'' - Michael Crichton
# 141. ''The Lost World'' - Michael Crichton
# 142. ''The Kitchen God's Wife'' - Amy Tan
# 143. ''I Know This Much Is True'' - Wally Lamb
# 144. ''A Map of the World'' - Jane Hamilton
# 145. ''Rising Sun'' - MICHAEL CRICHTON
# 146. ''Face the Fire (Three Sisters Island Trilogy)'' - Nora Roberts
# 147. ''The Bonesetter's Daughter'' - Amy Tan
# 148. ''Tribulation Force: The Continuing Drama of Those Left Behind (Left Behind No. 2)'' - Tim LaHaye
# 149. ''Seven Up (A Stephanie Plum Novel)'' - Janet Evanovich
# 150. ''Don't Sweat the Small Stuff and It's All Small Stuff : Simple Ways to Keep the Little Things from Taking Over Your Life (Don't Sweat the Small Stuff Series)'' - Richard Carlson
# 151. ''The Tao of Pooh'' - Benjamin Hoff
# 152. ''Angela's Ashes: A Memoir'' - Frank McCourt
# 153. ''A Bend in the Road'' - Nicholas Sparks
# 154. ''Deception Point'' - Dan Brown
# 155. ''The God of Small Things'' - Arundhati Roy
# 156. ''All I Really Need to Know'' - ROBERT FULGHUM
# 157. ''High Five (A Stephanie Plum Novel)'' - Janet Evanovich
# 158. ''Drowning Ruth (Oprah's Book Club)'' - CHRISTINA SCHWARZ
# 159. ''The Green Mile'' - Stephen King
# 160. ''The King of Torts'' - JOHN GRISHAM
# 161. ''The Beach House'' - James Patterson
# 162. ''Jemima J: A Novel About Ugly Ducklings and Swans'' - Jane Green
# 163. ''Big Stone Gap: A Novel (Ballantine Reader's Circle)'' - Adriana Trigiani
# 164. ''The Two Towers (The Lord of the Rings, Part 2)'' - J.R.R. TOLKIEN
# 165. ''Chicken Soup for the Soul (Chicken Soup for the Soul)'' - Jack Canfield
# 166. ''How to Be Good'' - Nick Hornby
# 167. ''The Summons'' - John Grisham
# 168. ''At Home in Mitford (The Mitford Years)'' - Jan Karon
# 169. ''Sophie's World: A Novel About the History of Philosophy'' - Jostein Gaarder
# 170. ''Animal Farm'' - George Orwell
# 171. ''What Looks Like Crazy On An Ordinary Day'' - Pearl Cleage
# 172. ''One Door Away from Heaven'' - Dean R. Koontz
# 173. ''The Clan of the Cave Bear (Earth's Children (Paperback))'' - Jean M. Auel
# 174. ''Violets Are Blue'' - James Patterson
# 175. ''Prey: A Novel'' - Michael Crichton
# 176. ''The Alchemist: A Fable About Following Your Dream'' - Paulo Coelho
# 177. ''Life of Pi'' - Yann Martel
# 178. ''The Mists of Avalon'' - MARION ZIMMER BRADLEY
# 179. ''Black Notice'' - Patricia Daniels Cornwell
# 180. ''Fried Green Tomatoes at the Whistle Stop Cafe'' - Fannie Flagg
# 181. ''The English Patient'' - Michael Ondaatje
# 182. ''B Is for Burglar (Kinsey Millhone Mysteries (Paperback))'' - Sue Grafton
# 183. ''Digital Fortress : A Thriller'' - Dan Brown
# 184. ''The Return of the King (The Lord of the Rings, Part 3)'' - J.R.R. TOLKIEN
# 185. ''Black and Blue'' - ANNA QUINDLEN
# 186. ''Hot Six : A Stephanie Plum Novel (A Stephanie Plum Novel)'' - Janet Evanovich
# 187. ''Year of Wonders'' - Geraldine Brooks
# 188. ''The Rescue'' - Nicholas Sparks
# 189. ''Tara Road'' - Maeve Binchy
# 190. ''Who Moved My Cheese? An Amazing Way to Deal with Change in Your Work and in Your Life'' - Spencer Johnson
# 191. ''The Cider House Rules'' - John Irving
# 192. ''The Body Farm'' - Patricia Daniels Cornwell
# 193. ''Bag of Bones'' - Stephen King
# 194. ''The Girl Who Loved Tom Gordon'' - Stephen King
# 195. ''Insomnia'' - Stephen King
# 196. ''Dreamcatcher'' - Stephen King
# 197. ''The Color of Water: A Black Man's Tribute to His White Mother'' - James McBride
# 198. ''The Virgin Suicides'' - Jeffrey Eugenides
# 199. ''Kiss the Girls'' - James Patterson
# 200. ''Roses Are Red (Alex Cross Novels)'' - James Patterson
# 201. ''Politically Correct Bedtime Stories: Modern Tales for Our Life and Times'' - James Finn Garner
# 202. ''Heaven and Earth (Three Sisters Island Trilogy)'' - Nora Roberts
# 203. ''Girl in Hyacinth Blue'' - Susan Vreeland
# 204. ''The Amazing Adventures of Kavalier & Clay'' - Michael Chabon
# 205. ''Beloved (Plume Contemporary Fiction)'' - Toni Morrison
# 206. ''Anne Frank: The Diary of a Young Girl'' - ANNE FRANK
# 207. ''Slaughterhouse Five or the Children's Crusade: A Duty Dance With Death'' - Kurt Vonnegut
# 208. ''Circle of Friends'' - Maeve Binchy
# 209. ''Cruel & Unusual (Kay Scarpetta Mysteries (Paperback))'' - Patricia D. Cornwell
# 210. ''A Walk in the Woods: Rediscovering America on the Appalachian Trail (Official Guides to the Appalachian Trail)'' - Bill Bryson
# 211. ''Unnatural Exposure'' - Patricia Daniels Cornwell
# 212. ''Artemis Fowl (Artemis Fowl, Book 1)'' - Eoin Colfer
# 213. ''A Wrinkle In Time'' - MADELEINE L'ENGLE
# 214. ''The Last Precinct'' - Patricia Cornwell
# 215. ''A Painted House'' - JOHN GRISHAM
# 216. ''The Hundred Secret Senses'' - Amy Tan
# 217. ''The Pillars of the Earth'' - Ken Follett
# 218. ''Vinegar Hill (Oprah's Book Club (Paperback))'' - A. Manette Ansay
# 219. ''Good Omens'' - Neil Gaiman
# 220. ''P Is for Peril'' - Sue Grafton
# 221. ''Memoirs of a Geisha Uk'' - Arthur Golden
# 222. ''Needful Things'' - Stephen King
# 223. ''The Dark Half'' - Stephen King
# 224. ''The Tommyknockers'' - Stephen King
# 225. ''The Other Boleyn Girl'' - Philippa Gregory
# 226. ''Disclosure'' - Michael Crichton
# 227. ''Dune (Remembering Tomorrow)'' - Frank Herbert
# 228. ''The Last Time They Met : A Novel'' - Anita Shreve
# 229. ''Bleachers'' - John Grisham
# 230. ''Tell No One'' - Harlan Coben
# 231. ''Airframe'' - Michael Crichton
# 232. ''The King of Torts'' - John Grisham
# 233. ''Night'' - Elie Wiesel
# 234. ''Pop Goes the Weasel'' - James Patterson
# 235. ''On the Street Where You Live'' - Mary Higgins Clark
# 236. ''The Celestine Prophecy (Celestine Prophecy)'' - James Redfield
# 237. ''The Valley of Horses'' - JEAN M. AUEL
# 238. ''Running with Scissors: A Memoir'' - Augusten Burroughs
# 239. ''The Giver (21st Century Reference)'' - LOIS LOWRY
# 240. ''Dragonfly in Amber'' - DIANA GABALDON
# 241. ''Tis : A Memoir'' - Frank McCourt
# 242. ''The Bourne Identity'' - Robert Ludlum
# 243. ''Cat & Mouse (Alex Cross Novels)'' - James Patterson
# 244. ''Isle of Dogs'' - Patricia Cornwell
# 245. ''One for the Money (A Stephanie Plum Novel)'' - Janet Evanovich
# 246. ''Under the Tuscan Sun'' - Frances Mayes
# 247. ''The Saving Graces: A Novel'' - Patricia Gaffney
# 248. ''The Prince of Tides'' - Pat Conroy
# 249. ''Shopaholic Ties the Knot'' - Sophie Kinsella
# 250. ''The Hot Zone'' - Richard Preston
# 251. ''The Thorn Birds'' - Colleen McCullough
# 252. ''Jewel'' - Bret Lott
# 253. ''The Eyre Affair: A Novel'' - Jasper Fforde
# 254. ''From the Corner of His Eye'' - Dean Koontz
# 255. ''Animal Dreams'' - Barbara Kingsolver
# 256. ''Bridget Jones's Diary'' - Helen Fielding
# 257. ''Heart of the Sea (Irish Trilogy)'' - Nora Roberts
# 258. ''Coraline'' - Neil Gaiman
# 259. ''A Lesson Before Dying (Vintage Contemporaries (Paperback))'' - Ernest J. Gaines
# 260. ''A Wrinkle in Time'' - Madeleine L'Engle
# 261. ''Brave New World'' - Aldous Huxley
# 262. ''Gerald's Game'' - Stephen King
# 263. ''Hearts in Atlantis'' - Stephen King
# 264. ''A Thousand Acres (Ballantine Reader's Circle)'' - JANE SMILEY
# 265. ''Hard Eight : A Stephanie Plum Novel (A Stephanie Plum Novel)'' - Janet Evanovich
# 266. ''Prey'' - Michael Crichton
# 267. ''Point of Origin'' - Patricia Daniels Cornwell
# 268. ''The Stand: Complete and Uncut'' - Stephen King
# 269. ''\O\" Is for Outlaw"'' - SUE GRAFTON
# 270. ''Neuromancer (Remembering Tomorrow)'' - William Gibson
# 271. ''Holes (Yearling Newbery)'' - LOUIS SACHAR
# 272. ''Bee Season: A Novel'' - Myla Goldberg
# 273. ''The Princess Bride: S Morgenstern's Classic Tale of True Love and High Adventure'' - WILLIAM GOLDMAN
# 274. ''Zen and the Art of Motorcycle Maintenance: An Inquiry into Values'' - ROBERT PIRSIG
# 275. ''I Know This Much Is True (Oprah's Book Club)'' - Wally Lamb
# 276. ''The Lost Boy: A Foster Child's Search for the Love of a Family'' - Dave Pelzer
# 277. ''Ishmael: An Adventure of the Mind and Spirit'' - Daniel Quinn
# 278. ''Nicolae: The Rise of Antichrist (Left Behind No. 3)'' - Tim F. Lahaye
# 279. ''Secret History'' - DONNA TARTT
# 280. ''The Beach House'' - James Patterson
# 281. ''Bridget Jones's Diary'' - Helen Fielding
# 282. ''Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series (Paper))'' - Jack Canfield
# 283. ''Jack & Jill (Alex Cross Novels)'' - James Patterson
# 284. ''The Golden Compass (His Dark Materials, Book 1)'' - PHILIP PULLMAN
# 285. ''Naked'' - David Sedaris
# 286. ''Ellen Foster'' - Kaye Gibbons
# 287. ''The Andromeda Strain'' - MICHAEL CRICHTON
# 288. ''Hearts In Atlantis'' - Stephen King
# 289. ''Here on Earth'' - Alice Hoffman
# 290. ''Shopgirl'' - Steve Martin
# 291. ''G Is for Gumshoe (Kinsey Millhone Mysteries (Paperback))'' - Sue Grafton
# 292. ''Charlotte's Web (Trophy Newbery)'' - E. B. White
# 293. ''Plainsong (Vintage Contemporaries)'' - KENT HARUF
# 294. ''Atonement : A Novel'' - IAN MCEWAN
# 295. ''Bridget Jones : The Edge of Reason'' - Helen Fielding
# 296. ''Sisterhood of the Traveling Pants'' - ANN BRASHARES
# 297. ''I Know Why the Caged Bird Sings'' - MAYA ANGELOU
# 298. ''What to Expect When You're Expecting (Revised Edition)'' - Arlene Eisenberg
# 299. ''Jewels of the Sun (Irish Trilogy)'' - Nora Roberts
# 300. ''The Girls' Guide to Hunting and Fishing'' - Melissa Bank
# 301. ''Contact'' - Carl Sagan
# 302. ''The Color Purple'' - Alice Walker
# 303. ''The Color Purple'' - Alice Walker
# 304. ''The Rapture of Canaan'' - Sheri Reynolds
# 305. ''The Brethren'' - JOHN GRISHAM
# 306. ''Lamb : The Gospel According to Biff, Christ's Childhood Pal'' - Christopher Moore
# 307. ''River, Cross My Heart'' - Breena Clarke
# 308. ''Lucky Man: A Memoir'' - Michael J. Fox
# 309. ''Tears of the Moon (Irish Trilogy)'' - Nora Roberts
# 310. ''Stranger in a Strange Land (Remembering Tomorrow)'' - Robert A. Heinlein
# 311. ''Suzanne's Diary for Nicholas'' - James Patterson
# 312. ''Suzanne's Diary for Nicholas'' - James Patterson
# 313. ''False Memory'' - Dean R. Koontz
# 314. ''Cradle and All'' - James Patterson
# 315. ''Lies and the Lying Liars Who Tell Them: A Fair and Balanced Look at the Right'' - Al Franken
# 316. ''White Teeth: A Novel'' - Zadie Smith
# 317. ''Eats, Shoots & Leaves: The Zero Tolerance Approach to Punctuation'' - Lynne Truss
# 318. ''The Shipping News : A Novel'' - Annie Proulx
# 319. ''Hornet's Nest'' - Patricia Daniels Cornwell
# 320. ''The Last Juror'' - John Grisham
# 321. ''To the Nines: A Stephanie Plum Novel'' - Janet Evanovich
# 322. ''D Is for Deadbeat (Kinsey Millhone Mysteries (Paperback))'' - Sue Grafton
# 323. ''All That Remains (Kay Scarpetta Mysteries (Paperback))'' - Patricia D. Cornwell
# 324. ''A Confederacy of Dunces (Evergreen Book)'' - John Kennedy Toole
# 325. ''The Handmaid's Tale : A Novel'' - Margaret Atwood
# 326. ''Midnight in the Garden of Good and Evil'' - John Berendt
# 327. ''The Murder Book'' - Jonathan Kellerman
# 328. ''Dolores Claiborne'' - Stephen King
# 329. ''In Her Shoes : A Novel'' - Jennifer Weiner
# 330. ''Fear Nothing'' - DEAN KOONTZ
# 331. ''Catch Me If You Can: The True Story of a Real Fake'' - Stan Redding
# 332. ''Five Quarters of the Orange'' - Joanne Harris
# 333. ''Daisy Fay and the Miracle Man'' - Fannie Flagg
# 334. ''Nights in Rodanthe'' - Nicholas Sparks
# 335. ''Cause of Death'' - Patricia Daniels Cornwell
# 336. ''Sick Puppy'' - Carl Hiaasen
# 337. ''Cold Mountain'' - Charles Frazier
# 338. ''The Hitchhiker's Guide to the Galaxy'' - Douglas Adams
# 339. ''The Devil Wears Prada : A Novel'' - LAUREN WEISBERGER
# 340. ''Postmortem'' - Patricia Daniels Cornwell
# 341. ''Scarlet Feather'' - Maeve Binchy
# 342. ''Middlesex: A Novel'' - Jeffrey Eugenides
# 343. ''Three Fates'' - Nora Roberts
# 344. ''Bastard Out of Carolina'' - Dorothy Allison
# 345. ''Songs in Ordinary Time (Oprah's Book Club (Paperback))'' - Mary McGarry Morris
# 346. ''Carolina Moon'' - Nora Roberts
# 347. ''The Gunslinger (The Dark Tower, Book 1)'' - Stephen King
# 348. ''American Psycho (Vintage Contemporaries)'' - Bret Easton Ellis
# 349. ''East of Eden (Oprah's Book Club)'' - John Steinbeck
# 350. ''J Is for Judgment'' - Sue Grafton
# 351. ''The Blue Nowhere : A Novel'' - Jeffery Deaver
# 352. ''C Is for Corpse (Kinsey Millhone Mysteries (Paperback))'' - Sue Grafton
# 353. ''Falling Angels'' - Tracy Chevalier
# 354. ''The Corrections: A Novel'' - Jonathan Franzen
# 355. ''H Is for Homicide (Kinsey Millhone Mysteries (Paperback))'' - Sue Grafton
# 356. ''The Weight of Water : A Novel Tag: Author of Resistance and Strange Fits of Passion'' - Anita Shreve
# 357. ''I Is for Innocent'' - Sue Grafton
# 358. ''The Stone Diaries'' - Carol Shields
# 359. ''Suzanne's Diary for Nicholas'' - James Patterson
# 360. ''The Hours : A Novel'' - Michael Cunningham
# 361. ''Four Blind Mice'' - James Patterson
# 362. ''Men Are from Mars, Women Are from Venus: A Practical Guide for Improving Communication and Getting What You Want in Your Relationships'' - John Gray
# 363. ''The Street Lawyer'' - John Grisham
# 364. ''The House of the Spirits'' - Isabel Allende
# 365. ''F Is for Fugitive (Kinsey Millhone Mysteries (Paperback))'' - Sue Grafton
# 366. ''1st to Die: A Novel'' - James Patterson
# 367. ''The Mummy or Ramses the Damned'' - Anne Rice
# 368. ''A Widow for One Year'' - JOHN IRVING
# 369. ''Atlas Shrugged'' - Ayn Rand
# 370. ''The Partner'' - John Grisham
# 371. ''A Year in Provence'' - Peter Mayle
# 372. ''The Poisonwood Bible'' - Barbara Kingsolver
# 373. ''2nd Chance'' - James Patterson
# 374. ''Without Remorse'' - Tom Clancy
# 375. ''The House on Mango Street (Vintage Contemporaries)'' - SANDRA CISNEROS
# 376. ''Like Water for Chocolate: A Novel in Monthly Installments, With Recipes, Romances, and Home Remedies'' - Laura Esquivel
# 377. ''From a Buick 8 : A Novel'' - Stephen King
# 378. ''Anne of Green Gables (Anne of Green Gables Novels (Paperback))'' - L.M. MONTGOMERY
# 379. ''Miss Julia Speaks Her Mind : A Novel'' - Ann B. Ross
# 380. ''The Curious Incident of the Dog in the Night-Time (Today Show Book Club #13)'' - Mark Haddon
# 381. ''Presumed Innocent'' - Scott Turow
# 382. ''Love in the Time of Cholera (Penguin Great Books of the 20th Century)'' - Gabriel Garcia Marquez
# 383. ''The World According to Garp'' - John Irving
# 384. ''Like Water for Chocolate: A Novel in Monthly Installments With Recipes, Romances and Home Remedies'' - Laura Esquivel
# 385. ''Like Water for Chocolate : A Novel in Monthly Installments with Recipes, Romances, and Home Remedies'' - LAURA ESQUIVEL
# 386. ''The Bean Trees'' - Barbara Kingsolver
# 387. ''The Phantom Tollbooth'' - Norton Juster
# 388. ''Blow Fly: A Scarpetta Novel'' - Patricia Cornwell
# 389. ''E Is for Evidence: A Kinsey Millhone Mystery (Kinsey Millhone Mysteries (Paperback))'' - Sue Grafton
# 390. ''The Girl Who Loved Tom Gordon : A Novel'' - Stephen King
# 391. ''A Separate Peace'' - John Knowles
# 392. ''Interpreter of Maladies'' - Jhumpa Lahiri
# 393. ''Visions of Sugar Plums'' - Janet Evanovich
# 394. ''About a Boy (Movie Tie-In)'' - Nick Hornby
# 395. ''Q Is for Quarry'' - Sue Grafton
# 396. ''Final Target'' - Iris Johansen
# 397. ''The Rainmaker'' - John Grisham
# 398. ''The Smoke Jumper'' - Nicholas Evans
# 399. ''One Flew Over the Cuckoo's Nest'' - Ken Kesey
# 400. ''All Around the Town'' - Mary Higgins Clark
# 401. ''What to Expect the First Year'' - Arlene Eisenberg
# 402. ''Fast Women'' - Jennifer Crusie
# 403. ''Back When We Were Grownups : A Novel (Ballantine Reader's Circle)'' - ANNE TYLER
# 404. ''Chosen Prey'' - John Sandford
# 405. ''Loves Music, Loves to Dance'' - Mary Higgins Clark
# 406. ''Wifey'' - Judy Blume
# 407. ''The Pilot's Wife : A Novel Tag: Author of the Weight of Water (Oprah's Book Club (Hardcover))'' - Anita Shreve
# 408. ''The Eye of the World (The Wheel of Time, Book 1)'' - Robert Jordan
# 409. ''Their Eyes Were Watching God: A Novel'' - Zora Neale Hurston
# 410. ''The Virgin Blue'' - Tracy Chevalier
# 411. ''Timeline'' - Michael Crichton
# 412. ''Tis: A Memoir'' - Frank McCourt
# 413. ''The Glass Lake'' - Maeve Binchy
# 414. ''Open House'' - Elizabeth Berg
# 415. ''Welcome to the World, Baby Girl!'' - Fannie Flagg
# 416. ''Southern Cross'' - Patricia Daniels Cornwell
# 417. ''Jonathan Livingston Seagull'' - Richard Bach
# 418. ''Key of Valor (Roberts, Nora. Key Trilogy, 3.)'' - Nora Roberts
# 419. ''L Is for Lawless'' - Sue Grafton
# 420. ''Song of Solomon (Oprah's Book Club (Paperback))'' - Toni Morrison
# 421. ''Hard Eight : A Stephanie Plum Novel (A Stephanie Plum Novel)'' - Janet Evanovich
# 422. ''The Shelters of Stone (Earth's Children Series, No 5)'' - JEAN M. AUEL
# 423. ''Soul Harvest: The World Takes Sides (Left Behind No. 4)'' - Tim Lahaye
# 424. ''The Four Agreements: A Practical Guide to Personal Freedom'' - Don Miguel Ruiz
# 425. ''The Chamber'' - John Grisham
# 426. ''N Is for Noose'' - Sue Grafton
# 427. ''Hearts In Atlantis : New Fiction'' - Stephen King
# 428. ''Dreamcatcher'' - Stephen King
# 429. ''Bridget Jones's Diary'' - Helen Fielding
# 430. ''The Reptile Room (A Series of Unfortunate Events, Book 2)'' - Lemony Snicket
# 431. ''Guilty Pleasures (Anita Blake Vampire Hunter (Paperback))'' - Laurell K. Hamilton
# 432. ''Night Sins'' - TAMI HOAG
# 433. ''Flesh and Blood'' - Jonathan Kellerman
# 434. ''Chocolat'' - Joanne Harris
# 435. ''The Honk and Holler Opening Soon'' - Billie Letts
# 436. ''Key of Knowledge (Key Trilogy (Paperback))'' - Nora Roberts
# 437. ''The Blind Assassin'' - Margaret Atwood
# 438. ''The Simple Truth'' - David Baldacci
# 439. ''Before I Say Good-Bye'' - Mary Higgins Clark
# 440. ''Charming Billy'' - Alice McDermott
# 441. ''The Curious Incident of the Dog in the Night-Time (Vintage Contemporaries)'' - Mark Haddon
# 442. ''Full Tilt (Janet Evanovich's Full Series)'' - Janet Evanovich
# 443. ''Deja Dead'' - Kathy Reichs
# 444. ''The Bluest Eye'' - Toni Morrison
# 445. ''Couplehood'' - PAUL REISER
# 446. ''The Talisman'' - STEPHEN KING
# 447. ''Monster : A Novel (Alex Delaware Novels (Paperback))'' - JONATHAN KELLERMAN
# 448. ''Watchers'' - Dean R. Koontz
# 449. ''The Dress Lodger (Ballantine Reader's Circle)'' - Sheri Holman
# 450. ''A Case of Need'' - Michael Crichton
# 451. ''The Last Time They Met : A Novel'' - Anita Shreve
# 452. ''Key of Light (Key Trilogy (Paperback))'' - Nora Roberts
# 453. ''The Hunt for Red October'' - Tom Clancy
# 454. ''The Summerhouse'' - Jude Deveraux
# 455. ''Ashes to Ashes'' - TAMI HOAG
# 456. ''Pay It Forward'' - Catherine Ryan Hyde
# 457. ''Three Junes'' - JULIA GLASS
# 458. ''Griffin & Sabine: An Extraordinary Correspondence'' - Nick Bantock
# 459. ''Midnight Bayou'' - Nora Roberts
# 460. ''Hannibal'' - Thomas Harris
# 461. ''Black House'' - Stephen King
# 462. ''Q Is for Quarry'' - Sue Grafton
# 463. ''Violets Are Blue'' - James Patterson
# 464. ''The Idiot Girls' Action Adventure Club'' - Laurie Notaro
# 465. ''Moonlight Becomes You'' - Mary Higgins Clark
# 466. ''The Testament'' - John Grisham
# 467. ''Beach Music'' - Pat Conroy
# 468. ''Pretend You Don't See Her'' - Mary Higgins Clark
# 469. ''Faking It'' - Jennifer Crusie
# 470. ''Seabiscuit'' - LAURA HILLENBRAND
# 471. ''The Loop'' - Nicholas Evans
# 472. ''Morality for Beautiful Girls (No.1 Ladies Detective Agency)'' - Alexander McCall Smith
# 473. ''Misery'' - Stephen King
# 474. ''Divine Secrets of the Ya-Ya Sisterhood : A Novel'' - Rebecca Wells
# 475. ''The Professor and the Madman: A Tale of Murder, Insanity, and the Making of The Oxford English Dictionary'' - Simon Winchester
# 476. ''Harry Potter and the Sorcerer's Stone (Book 1)'' - J. K. Rowling
# 477. ''Nightmares & Dreamscapes'' - Stephen King
# 478. ''The Lottery Winner : Alvirah And Willy Stories'' - Mary Higgins Clark
# 479. ''Me Talk Pretty One Day'' - David Sedaris
# 480. ''High Fidelity'' - Nick Hornby
# 481. ''Evening Class'' - Maeve Binchy
# 482. ''A Fine Balance'' - Rohinton Mistry
# 483. ''Everything's Eventual : 14 Dark Tales'' - Stephen King
# 484. ''Catch 22'' - Joseph Heller
# 485. ''The Plains of Passage (Earth's Children (Paperback))'' - JEAN M. AUEL
# 486. ''Blessings'' - ANNA QUINDLEN
# 487. ''Body of Evidence (Kay Scarpetta Mysteries (Paperback))'' - Patricia D. Cornwell
# 488. ''The Bonfire of the Vanities'' - Tom Wolfe
# 489. ''On the Road'' - Jack Kerouac
# 490. ''Siddhartha'' - Hermann Hesse
# 491. ''Four Blondes'' - Candace Bushnell
# 492. ''The Winner'' - David Baldacci
# 493. ''Red Storm Rising'' - Tom Clancy
# 494. ''Portrait of a Killer: Jack the Ripper -- Case Closed'' - Patricia Cornwell
# 495. ''Manhattan Hunt Club'' - JOHN SAUL
# 496. ''One True Thing'' - Anna Quindlen
#
# --------------------------------------------------------
#
# Estamos criando um novo perfil de usuário.
# Nesse momento, solicitamos por favor os seus três livros favoritos da lista acima.
#
# --------------------------------------------------------
#
# Insira por favor o número dos três livros: (digite 0 para sair)
# 0
# Até mais ;)

# %%
### FUNÇÃO NÚMERO DE RECOMENDAÇÕES POR ID ###
# Função que retorna com o número de livros recomendados para o id solicitado

def numero_recomendacoes_por_id(df_br_filtrado, rating_matrix, rating_matrix_sparse, n_neighbors, user_id):

    # Verificando se o user_id é válido para nossa matriz
    if user_id not in rating_matrix.index:
        return "Usuário não encontrado :("

    # Encontrar a posição do usuário na matriz
    index_usuario = rating_matrix.index.get_loc(user_id)

    # Extraindo a linha completa de avaliações do usuário de acordo com user_id
    avaliacoes_usuario = rating_matrix_sparse[index_usuario]

    # Encontrar os vizinhos mais proximos (n_neighbors vizinhos)
    distancias, indices = knn_model.kneighbors(avaliacoes_usuario, n_neighbors+1)

    # Obter os IDs dos usuários vizinhos (excluindo o próprio usuário)
    lista_indices = indices.flatten()
    ids_vizinhos = rating_matrix.index[lista_indices][1:]

    # Coletar os livros avaliados pelos vizinhos
    filtro_vizinhos = df_br_filtrado['User-ID'].isin(ids_vizinhos)
    livros_vizinhos = set(df_br_filtrado[filtro_vizinhos]['ISBN'].unique())

    # Remover livros que o usuário já avaliou
    filtro_usuario = df_br_filtrado['User-ID'] == user_id
    livros_lidos = set(df_br_filtrado[filtro_usuario]['ISBN'].unique())

    # Obtendo o conjunto de livros vizinhos excetuando os livros já avaliados pelo próprio usuário
    livros_vizinhos_unicos = livros_vizinhos - livros_lidos

    # Gerando um dataframe apenas com as avaliações feitas pelos vizinhos
    df_avaliacoes_vizinhos = df_br_filtrado[filtro_vizinhos]

    # Gerando um dataframe com contagem e média
    df_ranking = df_avaliacoes_vizinhos[df_avaliacoes_vizinhos['ISBN'].isin(livros_vizinhos_unicos)].copy()
    contagem_e_media = df_ranking.groupby('ISBN')['Book-Rating'].agg(['count', 'mean']).reset_index()

    # Extraindo um dataframe apenas com os N livros recomendados
    livros_recomendados = contagem_e_media.sort_values(by=['mean', 'count'], ascending=[False, False])

    # Criando um merge dos livros recomendados com o dataframe df_books
    livros_recomendados_pareados = pd.merge(livros_recomendados, df_books, on='ISBN')

    return len(livros_recomendados_pareados)

# %%
# Exemplo: Executando função de número de recomendações por id (n_neighbors = 31, id = 503)
numero_recomendacoes_por_id(df_br_filtrado, rating_matrix, rating_matrix_sparse, 31, 503)
# Out:
# 38

# %%
# EXTRAINDO SUBCONJUNTO DE USER-IDS ÚNICOS DO DATAFRAME DF_BR_FILTRADO

# Criando array com todos os ids unicos do dataframe
ids_unicos = df_br_filtrado['User-ID'].unique()
# Determinando número de ids que será selecionado aleatoriamente
n_ids_selecionados = 1000
# Determinando a seed global para garantir reprodutibilidade
np.random.seed(123)
# Criando array com ids aleatoriamente selecionados
ids_selecionados = np.random.choice(ids_unicos, n_ids_selecionados, replace=False)

# %%
# CALCULANDO O NÚMERO DE RECOMENDAÇÔES MÉDIAS POR ID

# determinando n_neighbors
n_neighbors = 50

# criando uma lista vazia
lista_numero_recomendacoes = []

# criando um laço para calcular o número de recomendações individualmente por id
for i in range(len(ids_selecionados)):
    id = ids_selecionados[i]
    numero_recomendacoes = numero_recomendacoes_por_id(df_br_filtrado, rating_matrix, rating_matrix_sparse, n_neighbors+1, id)
    lista_numero_recomendacoes.append(numero_recomendacoes)

# obtendo valor médio, mínimo e máximo da lista
media_recomendacoes = np.mean(lista_numero_recomendacoes)
minimo_recomendacoes = np.min(lista_numero_recomendacoes)
maximo_recomendacoes = np.max(lista_numero_recomendacoes)

# obtendo número de recomendações superior a 10
numero_recomendacoes_maior_ou_igual_a_10 = np.sum(np.array(lista_numero_recomendacoes) >= 10)
porcentagem = numero_recomendacoes_maior_ou_igual_a_10/n_ids_selecionados*100

# printando valores obtidos
print("N_neighbors utilizados para gerar recomendações: ", n_neighbors)
print("Média de recomendações: ", media_recomendacoes)
print("Mínimo de recomendações: ", minimo_recomendacoes)
print("Máximo de recomendações: ", maximo_recomendacoes)
print("Porcentagem de recomendações maior ou igual a 10: ", porcentagem, "%")
# Out:
# N_neighbors utilizados para gerar recomendações:  50
# Média de recomendações:  481.669
# Mínimo de recomendações:  0
# Máximo de recomendações:  2390
# Porcentagem de recomendações maior ou igual a 10:  99.3 %
